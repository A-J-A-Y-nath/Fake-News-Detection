# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import re 
import string

# %%
import pickle

# %%
data_fake = pd.read_csv('Fake.csv') 
data_true = pd.read_csv('True.csv')

# %%
data_true.head(10)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
# 5  White House, Congress prepare for talks on spe...
# 6  Trump says Russia probe will be fair, but time...
# 7  Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8         Trump on Twitter (Dec 28) - Global Warming
# 9  Alabama official to certify Senator-elect Jone...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# 5  WEST PALM BEACH, Fla./WASHINGTON (Reuters) - T...  politicsNews
# 6  WEST PALM BEACH, Fla (Reuters) - President Don...  politicsNews
# 7  The following statements were posted to the ve...  politicsNews
# 8  The following statements were posted to the ve...  politicsNews
# 9  WASHINGTON (Reuters) - Alabama Secretary of St...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017
# 5  December 29, 2017
# 6  December 29, 2017
# 7  December 29, 2017
# 8  December 29, 2017
# 9  December 28, 2017

# %%
data_fake['class'] = 0
data_true['class'] = 1

# %%
data_fake.shape,data_true.shape
# Out:
# ((23481, 5), (21417, 5))

# %%
data_fake_manual_testing = data_fake.tail(10)
for i in range(23480,23470,-1):
    data_fake.drop([i], axis = 0 , inplace = True)

data_true_manual_testing = data_true.tail(10)
for i in range(21416,21406,-1):
    data_true.drop([i], axis = 0 , inplace = True)

# %%
data_fake_manual_testing.head()
# Out:
#                                                    title  \
# 23471  Seven Iranians freed in the prisoner swap have...
# 23472                      #Hashtag Hell & The Fake Left
# 23473  Astroturfing: Journalist Reveals Brainwashing ...
# 23474          The New American Century: An Era of Fraud
# 23475  Hillary Clinton: ‘Israel First’ (and no peace ...
#
#                                                     text      subject  \
# 23471  21st Century Wire says This week, the historic...  Middle-east
# 23472   By Dady Chery and Gilbert MercierAll writers ...  Middle-east
# 23473  Vic Bishop Waking TimesOur reality is carefull...  Middle-east
# 23474  Paul Craig RobertsIn the last years of the 20t...  Middle-east
# 23475  Robert Fantina CounterpunchAlthough the United...  Middle-east
#
#                    date  class
# 23471  January 20, 2016      0
# 23472  January 19, 2016      0
# 23473  January 19, 2016      0
# 23474  January 19, 2016      0
# 23475  January 18, 2016      0

# %%
data_merge = pd.concat([data_fake , data_true], axis = 0)

# %%
data_merge.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
data = data_merge.drop(['title','subject','date'], axis=1)

# %%
data.head(10)
# Out:
#                                                 text  class
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0
# 5  The number of cases of cops brutalizing and ki...      0
# 6  Donald Trump spent a good portion of his day a...      0
# 7  In the wake of yet another court decision that...      0
# 8  Many people have raised the alarm regarding th...      0
# 9  Just when you might have thought we d get a br...      0

# %%
data.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %%
data = data.sample(frac =1)

# %%
data.head()
# Out:
#                                                     text  class
# 8603   Ted Cruz is fast approaching Donald Trump as t...      0
# 10483  FLINT, Mich. (Reuters) - Democratic presidenti...      1
# 10107  The news that the forecast for the third quart...      0
# 12543  PARIS (Reuters) - French state-controlled util...      1
# 8221   MEXICO CITY (Reuters) - Mexico’s new finance m...      1

# %%
data.reset_index(inplace = True)

# %%
data.head()
# Out:
#    index                                               text  class
# 0   8603  Ted Cruz is fast approaching Donald Trump as t...      0
# 1  10483  FLINT, Mich. (Reuters) - Democratic presidenti...      1
# 2  10107  The news that the forecast for the third quart...      0
# 3  12543  PARIS (Reuters) - French state-controlled util...      1
# 4   8221  MEXICO CITY (Reuters) - Mexico’s new finance m...      1

# %%
data.drop(['index'],axis = 1,inplace = True)

# %%
data.head()
# Out:
#                                                 text  class
# 0  Ted Cruz is fast approaching Donald Trump as t...      0
# 1  FLINT, Mich. (Reuters) - Democratic presidenti...      1
# 2  The news that the forecast for the third quart...      0
# 3  PARIS (Reuters) - French state-controlled util...      1
# 4  MEXICO CITY (Reuters) - Mexico’s new finance m...      1

# %%
def wordopt(text):
    text = text.lower()  # Convert text to lowercase
    
    text = re.sub(r".*?", "", text)  # Remove text inside square brackets
    text = re.sub(r"[^\w\s]", "", text)  # Remove punctuation but keep spaces
    text = re.sub(r'https?://\S+|www\.\S+', "", text)  # Remove URLs
    text = re.sub(r'<.*?>+', "", text)  # Remove HTML tags
    text = re.sub(r"[%s]" % re.escape(string.punctuation), "", text)  # Remove punctuation
    text = re.sub(r'\n', "", text)  # Remove newlines
    text = re.sub(r'\w*\d\w*', "", text)  # Remove words containing numbers
    
    return text

# %%
data['text'] = data['text'].apply(wordopt)

# %%
data.head(10)
# Out:
#                                                 text  class
# 0  ted cruz is fast approaching donald trump as t...      0
# 1  flint mich reuters  democratic presidential co...      1
# 2  the news that the forecast for the third quart...      0
# 3  paris reuters  french statecontrolled utility ...      1
# 4  mexico city reuters  mexicos new finance minis...      1
# 5  white supremacists have been emboldened by don...      0
# 6   no challenge  poses a greater threat to futur...      0
# 7  in the interest of wasting as much time and en...      0
# 8  in a convenient distraction from trump s recen...      0
# 9  washington reuters  us president donald trump ...      1

# %%
x = data['text']
y = data['class']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()

# Fit the vectorizer on the training data and transform it
xv_train = vectorization.fit_transform(x_train)  

# Transform the test data using the fitted vectorizer
xv_test = vectorization.transform(x_test)

# %%
# Save the TF-IDF vectorizer
with open("tfidf_vectorizer.pkl", "wb") as vectorizer_file:
    pickle.dump(vectorization, vectorizer_file)

# %%
# this is logistic regression

# %%
from sklearn.linear_model import LogisticRegression  # Fixed import statement

# Initialize the Logistic Regression model
LR = LogisticRegression()

# Train (fit) the model using the training data
LR.fit(xv_train, y_train)  # Fixed typo in "xv_train"
# Out:
# LogisticRegression()

# %%
# Predict the labels for the test data
pred_lr = LR.predict(xv_test)  # Fixed typo in "pred_lr" and assignment

# %%
# Calculate and print the model accuracy on the test set
accuracy = LR.score(xv_test, y_test)  # Fixed typo in "y_test"

# %%
print("Predictions:", pred_lr)
print("Accuracy:", accuracy)
# Out:
# Predictions: [1 1 1 ... 0 1 1]
# Accuracy: 0.988680926916221

# %%
print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5805
#            1       0.99      0.99      0.99      5415
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %%
with open("logistic_model.pkl", "wb") as model_file:
    pickle.dump(LR, model_file)

# %%
#desicion tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)

# %%
DT.score(xv_test,y_test)
# Out:
# 0.995632798573975

# %%
print(classification_report(y_test,pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5805
#            1       1.00      1.00      1.00      5415
#
#     accuracy                           1.00     11220
#    macro avg       1.00      1.00      1.00     11220
# weighted avg       1.00      1.00      1.00     11220

# %%
with open("Decision_tree_model.pkl", "wb") as model_file:
    pickle.dump(DT, model_file)

# %%
from sklearn.ensemble import GradientBoostingClassifier
GB = GradientBoostingClassifier(random_state = 0)
GB.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
pred_gb = GB.predict(xv_test)

# %%
GB.score(xv_test,y_test)
# Out:
# 0.9949197860962566

# %%
print(classification_report(y_test,pred_gb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5805
#            1       0.99      1.00      0.99      5415
#
#     accuracy                           0.99     11220
#    macro avg       0.99      1.00      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %%
with open("GradientBooster_model.pkl", "wb") as model_file:
    pickle.dump(GB, model_file)

# %%
#random forrest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(random_state = 0)
RF.fit(xv_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred_rf = RF.predict(xv_test)

# %%
RF.score(xv_test,y_test)
# Out:
# 0.9851158645276292

# %%
print(classification_report(y_test,pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      5805
#            1       0.98      0.99      0.98      5415
#
#     accuracy                           0.99     11220
#    macro avg       0.98      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %%
with open("RandomForest_model.pkl", "wb") as model_file:
    pickle.dump(RF, model_file)

# %%
def output_lable(n):
    if n==0:
        return "Fake News"
    elif n==1:
        return "Not A Fake News"
    
def manual_testing(news):
    testing_news = {"text":[news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test['text'] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_LR = LR.predict(new_xv_test)
    pred_DT = DT.predict(new_xv_test)
    pred_GB = GB.predict(new_xv_test)
    pred_RF = RF.predict(new_xv_test)
    
    return print("\n\nLR Predicition: {} \nDT Prediction: {} \nGBC Prediction: {} \nRFC Prediction:{}".format(output_lable(pred_LR[0]),
                                                                                                             output_lable(pred_DT[0]),
                                                                                                             output_lable(pred_GB[0]),
                                                                                                             output_lable(pred_RF[0])))

# %%
news = str(input("Enter the news : "))
manual_testing(news)
# Out:
# Enter the news :  An Israeli drone strike has killed Mohammad Shaheen, the head of Hamas' military operations in Lebanon. This event coincides with Israel's announcement to delay the withdrawal of its troops from five strategic locations in southern Lebanon, despite an existing ceasefire agreement. The Israeli military claims Shaheen was orchestrating attacks funded by Iran. Lebanon's government has expressed opposition to the postponed pullout. Additionally, Prime Minister Benjamin Netanyahu's testimony in his criminal trial was canceled again for security reasons, and Lebanon extended its suspension of flights to and from Iran, leading to protests by Hezbollah supporters. Both nations have accused each other of ceasefire violations
# LR Predicition: Not A Fake News
# DT Prediction: Not A Fake News
# GBC Prediction: Not A Fake News
# RFC Prediction:Not A Fake News
